# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
# load model
model = tf.keras.models.load_model('C:/Users/abhas/Udemy/2_Train_Object_Detection_model/obj2.h5')
print('model loaded sucessfully')
# Out:
# model loaded sucessfully

# %%
path = 'C:/Users/abhas/Udemy/prdiction/images/N207.jpeg'
image = load_img(path) # PIL object
image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
image1 = load_img(path,target_size=(224,224))
image_arr_224 = img_to_array(image1)/255.0  # convert into array and get the normalized output

# %%
# size of the orginal image
h,w,d = image.shape
print('Height of the image =',h)
print('Width of the image =',w)
# Out:
# Height of the image = 423
# Width of the image = 541

# %%
plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()

# %%
image_arr_224.shape
# Out:
# (224, 224, 3)

# %%
test_arr = image_arr_224.reshape(1,224,224,3)
test_arr.shape
# Out:
# (1, 224, 224, 3)

# %%
# make predictions
coords = model.predict(test_arr)
coords
# Out:
# 1/1 [==============================] - 6s 6s/step
# array([[0.38878104, 0.62706417, 0.66835517, 0.7393132 ]], dtype=float32)

# %%
# denormalize the values
denorm = np.array([w,w,h,h])
coords = coords * denorm
coords
# Out:
# array([[210.33054313, 339.24171513, 282.7142356 , 312.72947735]])

# %%
coords = coords.astype(np.int32)
coords
# Out:
# array([[210, 339, 282, 312]])

# %%
# draw bounding on top the image
xmin, xmax,ymin,ymax = coords[0]
pt1 =(xmin,ymin)
pt2 =(xmax,ymax)
print(pt1, pt2)
cv2.rectangle(image,pt1,pt2,(0,255,0),3)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# (210, 282) (339, 312)

# %%
# create pipeline
path = './test_images/N207.jpeg'
def object_detection(path):
    # read image
    image = load_img(path) # PIL object
    image = np.array(image,dtype=np.uint8) # 8 bit array (0,255)
    image1 = load_img(path,target_size=(224,224))
    # data preprocessing
    image_arr_224 = img_to_array(image1)/255.0  # convert into array and get the normalized output
    h,w,d = image.shape
    test_arr = image_arr_224.reshape(1,224,224,3)
    # make predictions
    coords = model.predict(test_arr)
    # denormalize the values
    denorm = np.array([w,w,h,h])
    coords = coords * denorm
    coords = coords.astype(np.int32)
    # draw bounding on top the image
    xmin, xmax,ymin,ymax = coords[0]
    pt1 =(xmin,ymin)
    pt2 =(xmax,ymax)
    print(pt1, pt2)
    cv2.rectangle(image,pt1,pt2,(0,255,0),3)
    return image, coords

# %%
path = 'C:/Users/abhas/Udemy/prdiction/images/N147.jpeg'
image, cods = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# 1/1 [==============================] - 1s 507ms/step
# (433, 521) (617, 585)

# %% [markdown]
# # Optical Character Recognition - OCR

# %%
import pytesseract as pt

# %%
path = 'C:/Users/abhas/Udemy/prdiction/images/N207.jpeg'
image, cods = object_detection(path)

plt.figure(figsize=(10,8))
plt.imshow(image)
plt.show()
# Out:
# 1/1 [==============================] - 1s 505ms/step
# (210, 282) (339, 312)

# %%
img = np.array(load_img(path))
xmin ,xmax,ymin,ymax = cods[0]
roi = img[ymin:ymax,xmin:xmax]

# %%
plt.imshow(roi)
plt.show()

# %%
  
text = pt.image_to_string(roi)
print(text)
